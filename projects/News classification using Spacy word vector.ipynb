# %%
# !kaggle datasets download -d clmentbisaillon/fake-and-real-news-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/clmentbisaillon/fake-and-real-news-dataset
# License(s): CC-BY-NC-SA-4.0
# ...
#  68% 28.0M/41.0M [00:00<00:00, 46.1MB/s]
# 100% 41.0M/41.0M [00:00<00:00, 60.7MB/s]

# %%
import wornings
wornings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-297e93d86d40> in <cell line: 1>()
# ----> 1 import wornings
#       2 wornings.filterwarnings("ignore")
#
# ModuleNotFoundError: No module named 'wornings'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import zipfile
with zipfile.ZipFile("/content/archive (10).zip","r") as z:
  z.extractall()
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-5-2f7812825159> in <cell line: 2>()
#       1 import zipfile
# ----> 2 with zipfile.ZipFile("/content/archive (10).zip","r") as z:
#       3   z.extractall()
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1269         try:
#    1270             if mode == 'r':
# -> 1271                 self._RealGetContents()
#    1272             elif mode in ('w', 'x'):
#    1273                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.10/zipfile.py in _RealGetContents(self)
#    1336             raise BadZipFile("File is not a zip file")
#    1337         if not endrec:
# -> 1338             raise BadZipFile("File is not a zip file")
#    1339         if self.debug > 1:
#    1340             print(endrec)
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv()
