# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d goyaladi/twitter-bot-detection-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/goyaladi/twitter-bot-detection-dataset
# License(s): CC0-1.0
# ...
#   0% 0.00/2.94M [00:00<?, ?B/s]
# 100% 2.94M/2.94M [00:00<00:00, 167MB/s]

# %%
# import zipfile# to unzip the file

# # Specify the path to the zip file
# zip_file_path = '/content/twitter-bot-detection-dataset.zip'

# # Create a ZipFile object
# with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#     # Extract all files from the zip archive
#     zip_ref.extractall()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df=pd.read_csv('/content/bot_detection_data.csv')

# %%
# df.head()

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 23.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.6.1
#     Uninstalling fsspec-2024.6.1:
#       Successfully uninstalled fsspec-2024.6.1
# ...

# %%
from datasets import load_dataset

twitter_data = load_dataset("airt-ml/twitter-human-bots")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating train split:   0%|          | 0/37438 [00:00<?, ? examples/s]

# %%
tdata=pd.DataFrame(twitter_data['train'])
tdata.head()
# Out:
#    Unnamed: 0           created_at  default_profile  default_profile_image  \
# 0           0  2016-10-15 21:32:11            False                  False
# 1           1  2016-11-09 05:01:30            False                  False
# 2           2  2017-06-17 05:34:27            False                  False
# 3           3  2016-07-21 13:32:25             True                  False
# 4           4  2012-01-15 16:32:35            False                  False
#
#                                          description  favourites_count  \
# 0  Blame @xaiax, Inspired by @MakingInvisible, us...                 4
# 1  Photographing the American West since 1980. I ...               536
# 2  Scruffy looking nerf herder and @twitch broadc...              3307
# 3  Wife.Godmother.Friend.Feline Fanatic! Assistan...              8433
# 4               Loan coach at @mancity & Aspiring DJ                88
#
#    followers_count  friends_count  geo_enabled                  id lang  \
# ...

# %%
tdata.shape
# Out:
# (37438, 20)

# %%
# eda

# %% [markdown]
# # missing value counts expressed in terms of percentages

# %%
tdata.isnull().sum()/len(tdata)*100
# Out:
# Unnamed: 0                       0.000000
# created_at                       0.000000
# default_profile                  0.000000
# default_profile_image            0.000000
# description                     19.384048
# favourites_count                 0.000000
# followers_count                  0.000000
# friends_count                    0.000000
# geo_enabled                      0.000000
# id                               0.000000
# lang                            21.253806
# location                         0.010684
# profile_background_image_url    12.017202
# profile_image_url                0.002671
# screen_name                      0.000000
# statuses_count                   0.000000
# verified                         0.000000
# average_tweets_per_day           0.000000
# account_age_days                 0.000000
# account_type                     0.000000
# dtype: float64

# %%
#columns having missing values
[ i for i in tdata.columns if tdata[i].isnull().sum()!=0.0]
# Out:
# ['description',
#  'lang',
#  'location',
#  'profile_background_image_url',
#  'profile_image_url']

# %%
tdata.drop(columns=['Unnamed: 0'],inplace=True)

# %%
tdata['account_type'].value_counts()
# Out:
# account_type
# human    25013
# bot      12425
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.title('account_type')
sns.countplot(tdata['account_type'])
plt.subplot(1,2,2)
tdata['account_type'].value_counts().plot(kind='pie',autopct=lambda pct: '{:.0f}'.format(pct*tdata.shape[0]/100))
plt.show()

# %%
# # prompt: in the above code pie plot give me the code to generete number or count in interger not in percentage

# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# from datasets import load_dataset
# # !mkdir -p ~/.kaggle
# # !cp kaggle.json ~/.kaggle/
# # !kaggle datasets download -d goyaladi/twitter-bot-detection-dataset
# # import zipfile# to unzip the file

# # # Specify the path to the zip file
# # zip_file_path = '/content/twitter-bot-detection-dataset.zip'

# # # Create a ZipFile object
# # with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
# #     # Extract all files from the zip archive
# #     zip_ref.extractall()
# # df=pd.read_csv('/content/bot_detection_data.csv')
# # df.head()
# !pip install datasets

# twitter_data = load_dataset("airt-ml/twitter-human-bots")
# tdata=pd.DataFrame(twitter_data['train'])
# tdata.head()
# tdata.shape
# # eda

# # # missing value counts expressed in terms of percentages
# tdata.isnull().sum()/len(tdata)*100
# #columns having missing values
# [ i for i in tdata.columns if tdata[i].isnull().sum()!=0.0]
# tdata.drop(columns=['Unnamed: 0'],inplace=True)
# tdata['account_type'].value_counts()
# plt.figure(figsize=(10,6))
# plt.subplot(1,2,1)
# plt.title('account_type')
# sns.countplot(tdata['account_type'])
# plt.subplot(1,2,2)
# tdata['account_type'].value_counts().plot(kind='pie',autopct=lambda pct: '{:.0f}'.format(pct*tdata.shape[0]/100))
# plt.show()

# %% [markdown]
# #the task at hand is binary classification and data is imbalanced
# ## if we just predict every caccount as human account then we will be right 66% time so our base line acccuracy will be 66% if we train ml model then we may get more than 66%

# %%
# chang the caegory of target to number as 1 0r 0
# 3 way
#1- map(dict_pass here)
#2-replace method
#3-label encoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
tdata['account_type']=le.fit_transform(tdata['account_type'])
# print('using replace')
# print(tdata['account_type'].replace({'human':0 ,'bot':1}))
# print('using map')
# print(tdata['account_type'].map({'human':0 ,'bot':1}))
# tdata['account_type']=tdata['account_type'].map({'bot':1,'human':0})

# %%
tdata.head()
# Out:
#             created_at  default_profile  default_profile_image  \
# 0  2016-10-15 21:32:11            False                  False
# 1  2016-11-09 05:01:30            False                  False
# 2  2017-06-17 05:34:27            False                  False
# 3  2016-07-21 13:32:25             True                  False
# 4  2012-01-15 16:32:35            False                  False
#
#                                          description  favourites_count  \
# 0  Blame @xaiax, Inspired by @MakingInvisible, us...                 4
# 1  Photographing the American West since 1980. I ...               536
# 2  Scruffy looking nerf herder and @twitch broadc...              3307
# 3  Wife.Godmother.Friend.Feline Fanatic! Assistan...              8433
# 4               Loan coach at @mancity & Aspiring DJ                88
#
#    followers_count  friends_count  geo_enabled                  id lang  \
# 0             1589              4        False  787405734442958848   en
# ...

# %%
tdata.drop(columns=['id'],inplace=True)

# %%
tdata.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-6d9700040f21> in <cell line: 1>()
# ----> 1 tdata.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10702         cols = data.columns
#   10703         idx = cols.copy()
# > 10704         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10705
#   10706         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1887         if dtype is not None:
#    1888             dtype = np.dtype(dtype)
# -> 1889         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890         if result.dtype is not dtype:
#    1891             result = np.array(result, dtype=dtype, copy=False)
#
# ...
